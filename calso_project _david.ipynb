# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from pandas.io.json import json_normalize
import numpy as np
import os
import scipy
import seaborn as sns
import pprint
import argparse
import requests
import json
import csv 
import re
from csv import DictWriter 
import scipy.stats as stats
api_key = "3wehnE_AzTfs5gM9jsz9eNESFZ9YnXrRlTK4Hs92C_Ye4nigKHxiA78Z1gT5zL2Cbb0JpWbpTOKtqtEPBSyavdGzncpSjVNu6XiKliJaiEuDx1NNY52jvvnRN4haW3Yx"

# %%
try:
    # For Python 3.0 and later
    from urllib.error import HTTPError
    from urllib.parse import quote
    from urllib.parse import urlencode
except ImportError:
    # Fall back to Python 2's urllib2 and urllib
    from urllib2 import HTTPError
    from urllib import quote
    from urllib import urlencode

# %%
#load dataset from yelp dataset challenge on kaggle
business_data_to_load = "yelp_business.csv"
yelp_business_df = pd.read_csv(business_data_to_load)

# %%
#visualize data set
yelp_business_df.drop(['business_id','neighborhood','latitude','longitude','is_open'], axis = 1, inplace = True)
yelp_business_df.head()
# Out:
#                          name                           address  \
# 0          "Dental by Design"        "4855 E Warner Rd, Ste B9"
# 1       "Stephen Szabo Salon"              "3101 Washington Rd"
# 2     "Western Motor Vehicle"          "6025 N 27th Ave, Ste 1"
# 3          "Sports Authority"  "5000 Arizona Mills Cr, Ste 435"
# 4  "Brick House Tavern + Tap"                    "581 Howe Ave"
#
#              city state postal_code  stars  review_count  \
# 0       Ahwatukee    AZ       85044    4.0            22
# 1        McMurray    PA       15317    3.0            11
# 2         Phoenix    AZ       85017    1.5            18
# 3           Tempe    AZ       85282    3.0             9
# 4  Cuyahoga Falls    OH       44221    3.5           116
#
#                                           categories
# 0  Dentists;General Dentistry;Health & Medical;Or...
# 1  Hair Stylists;Hair Salons;Men's Hair Salons;Bl...
# 2  Departments of Motor Vehicles;Public Services ...
# 3                            Sporting Goods;Shopping
# 4  American (New);Nightlife;Bars;Sandwiches;Ameri...

# %%
#visualize data specific to las vegas
df_lv = yelp_business_df.loc[yelp_business_df['city'].isin(['Las Vegas'])]
df_lv.head()
# Out:
#                    name                         address       city state  \
# 6          "BDJ Realty"      "2620 Regatta Dr, Ste 102"  Las Vegas    NV
# 7         "Soccer Zone"  "7240 W Lake Mead Blvd, Ste 4"  Las Vegas    NV
# 26  "Alfredo's Jewelry"       "5775 S Eastern, Ste 103"  Las Vegas    NV
# 41      "Task Electric"     "7260 Cimarron Rd, Ste 130"  Las Vegas    NV
# 48       "Star Nursery"              "5340 Boulder Hwy"  Las Vegas    NV
#
#    postal_code  stars  review_count  \
# 6        89128    4.0             5
# 7        89128    1.5             9
# 26       89119    4.5            23
# 41       89113    4.5            20
# 48       89122    3.5            25
#
#                                            categories
# 6   Real Estate Services;Real Estate;Home Services...
# 7                             Shopping;Sporting Goods
# 26       Shopping;Jewelry;Watch Repair;Local Services
# 41  Home Services;Lighting Fixtures & Equipment;Lo...
# 48       Nurseries & Gardening;Home & Garden;Shopping

# %%
#visualize restrant data from  las vegas
newdf = df_lv[df_lv['categories'].str.contains('Restaurants')]
newdf.head()
# Out:
#                           name                           address       city  \
# 52   "Flight Deck Bar & Grill"           "6730 S Las Vegas Blvd"  Las Vegas
# 53                    "Subway"     "6889 S Eastern Ave, Ste 101"  Las Vegas
# 54                 "GameWorks"  "6587 Las Vegas Blvd S, Ste 171"  Las Vegas
# 91            "Cafe Mastrioni"   "4250 S Rainbow Blvd, Ste 1007"  Las Vegas
# 122               "McDonald's"            "3020 E Desert Inn Rd"  Las Vegas
#
#     state postal_code  stars  review_count  \
# 52     NV       89119    4.0            13
# 53     NV       89119    2.5             6
# 54     NV       89119    3.0           349
# 91     NV       89103    1.5             3
# 122    NV       89121    2.0            20
#
#                                             categories
# 52   Nightlife;Bars;Barbeque;Sports Bars;American (...
# 53                    Fast Food;Restaurants;Sandwiches
# 54   Arcades;Arts & Entertainment;Gastropubs;Restau...
# 91                                 Italian;Restaurants
# 122                      Restaurants;Fast Food;Burgers

# %%
#distribution of las vegas ratings
x=newdf['stars'].value_counts()
x=x.sort_index()
#plot
plt.figure(figsize=(12,8))
ax= sns.barplot(x.index, x.values, alpha=0.8)
plt.title("LV Restraunt Ratings")
plt.ylabel("Star Distrubution")
plt.xlabel('Star Ratings ', fontsize=12)
# Out:
# Text(0.5,0,'Star Ratings ')

# %%
# Yelp Token
headers = {"Authorization": "Bearer NgQORIhh2PKDSoidMn4kghbdKzoQo_OsLUKIOkRR-9-XqMFvqD3Bx3BK5sUBjA5KsEbkVNDTyr_jjPwZKqIhQD6ND1OqvxQV3PwLcjBROS0Aw656xAsYq3TvUjxiW3Yx"}
counter = 0

# Loop through every zip code from new df
for index, row in df_lv.iterrows():
    
    # Add to counter
    counter = counter + 1
    
    # Create endpoint URLs that equate to 3 pages:
    target_url_lv = "https://api.yelp.com/v3/businesses/search?limit=50&term=Restraunts&location=%s" % (row["postal_code"])
    target_url_lv1 = "https://api.yelp.com/v3/businesses/search?offset=51&limit=50&term=Restraunts&location=%s" % (row["postal_code"])
    target_url_lv2= "https://api.yelp.com/v3/businesses/search?offset=101&term=Restraunts&location=%s" % (row["postal_code"])

    # Print the URLs to ensure logging
    print(counter)
    print(target_url_lv)
   
    # Json requests that gets the Yelp Restraunt data from url  
    yelp_reviews_restraunt = requests.get(target_url_lv, headers=headers).json()
    yelp_reviews_restraunt1 = requests.get(target_url_lv1, headers=headers).json()
    yelp_reviews_restraunt2 = requests.get(target_url_lv2, headers=headers).json()


    
    
    # Calculate the total reviews and weighted rankings
    lv_review_count = 0
    
    lv_weighted_review = 0
    pprint.pprint(yelp_reviews_restraunt)

# %%
json.dumps(yelp_reviews_restraunt)
# Out:
# '{"businesses": [{"id": "xfzDtGxx6B4a27RAyah69w", "alias": "sushi-21-las-vegas", "name": "Sushi 21", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/jNv9DMm4uWYXiewv3NWG0A/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/sushi-21-las-vegas?adjust_creative=5j21hCBOBFEtfZC9snDYKg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5j21hCBOBFEtfZC9snDYKg", "review_count": 701, "categories": [{"alias": "sushi", "title": "Sushi Bars"}, {"alias": "japanese", "title": "Japanese"}, {"alias": "breakfast_brunch", "title": "Breakfast & Brunch"}], "rating": 4.0, "coordinates": {"latitude": 36.1006939, "longitude": -115.2090751}, "transactions": ["delivery", "pickup"], "price": "$$", "location": {"address1": "4965 W Tropicana Ave", "address2": "Ste 102", "address3": "", "city": "Las Vegas", "zip_code": "89103", "country": "US", "state": "NV", "display_address": ["4965 W Tropicana Ave", "Ste 102", "Las Vegas, NV 89103"]}, "phone": "+17029522500", "display_phone": "(702) 952-2500", "distance": 2264.0403413338054}, {"id": "-1m9o3vGRA8IBPNvNqKLmA", "alias": "bavettes-steakhouse-and-bar-las-vegas-2", "name": "Bavette\'s Steakhouse & Bar", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/pgcnYRHtbw_x_-OG8K4xVg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/bavettes-steakhouse-and-bar-las-vegas-2?adjust_creative=5j21hCBOBFEtfZC9snDYKg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5j21hCBOBFEtfZC9snDYKg", "review_count": 204, "categories": [{"alias": "steak", "title": "Steakhouses"}, {"alias": "bars", "title": "Bars"}, {"alias": "newamerican", "title": "American (New)"}], "rating": 4.5, "coordinates": {"latitude": 36.10433, "longitude": -115.175593333333}, "transactions": [], "price": "$$$$", "location": {"address1": "3770 Las Vegas Blvd S", "address2": "", "address3": null, "city": "Las Vegas", "zip_code": "89109", "country": "US", "state": "NV", "display_address": ["3770 Las Vegas Blvd S", "Las Vegas, NV 89109"]}, "phone": "+17027306700", "display_phone": "(702) 730-6700", "distance": 4305.949625410216}, {"id": "aNe8ofTYrealxqv7VtFTuw", "alias": "sierra-gold-las-vegas", "name": "Sierra Gold", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/4TPczJMmMlht07ccX_Xtkw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/sierra-gold-las-vegas?adjust_creative=5j21hCBOBFEtfZC9snDYKg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5j21hCBOBFEtfZC9snDYKg", "review_count": 227, "categories": [{"alias": "newamerican", "title": "American (New)"}, {"alias": "breweries", "title": "Breweries"}, {"alias": "pizza", "title": "Pizza"}], "rating": 3.5, "coordinates": {"latitude": 36.0704, "longitude": -115.22495}, "transactions": [], "price": "$$", "location": {"address1": "6515 S Jones Blvd", "address2": "", "address3": "", "city": "Las Vegas", "zip_code": "89118", "country": "US", "state": "NV", "display_address": ["6515 S Jones Blvd", "Las Vegas, NV 89118"]}, "phone": "+17022214120", "display_phone": "(702) 221-4120", "distance": 1525.865584677713}, {"id": "mDR12Hafvr84ctpsV6YLag", "alias": "mr-mamas-las-vegas-7", "name": "Mr Mamas", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/jcFwekQsVKpXleKqcWUu2Q/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/mr-mamas-las-vegas-7?adjust_creative=5j21hCBOBFEtfZC9snDYKg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5j21hCBOBFEtfZC9snDYKg", "review_count": 2160, "categories": [{"alias": "breakfast_brunch", "title": "Breakfast & Brunch"}, {"alias": "tradamerican", "title": "American (Traditional)"}, {"alias": "burgers", "title": "Burgers"}], "rating": 4.5, "coordinates": {"latitude": 36.0864753723145, "longitude": -115.225959777832}, "transactions": [], "price": "$", "location": {"address1": "5693 S Jones Blvd", "address2": "Ste 106", "address3": "", "city": "Las Vegas", "zip_code": "89118", "country": "US", "state": "NV", "display_address": ["5693 S Jones Blvd", "Ste 106 ...

# %%
#
data= yelp_reviews_restraunt
data1 = yelp_reviews_restraunt1
data2 = yelp_reviews_restraunt2
#df = pd.DataFrame(data['businesses'])

#df = pd.DataFrame(data['businesses'], data1['businesses'],data2['businesses']) 
df = pd.DataFrame(data['businesses'] + data1['businesses'] + data2['businesses'])

df
# Out:
#                                                  alias  \
# 0                                   sushi-21-las-vegas
# 1              bavettes-steakhouse-and-bar-las-vegas-2
# 2                                sierra-gold-las-vegas
# 3                                 mr-mamas-las-vegas-7
[{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 12   [{'alias': 'breakfast_brunch', 'title': 'Break...
# 13   [{'alias': 'newamerican', 'title': 'American (...
# 14   [{'alias': 'hawaiian', 'title': 'Hawaiian'}, {...
# 15   [{'alias': 'french', 'title': 'French'}, {'ali...
# 16   [{'alias': 'japanese', 'title': 'Japanese'}, {...
# 17   [{'alias': 'soulfood', 'title': 'Soul Food'}, ...
# 18   [{'alias': 'tradamerican', 'title': 'American ...
# 19   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 20   [{'alias': 'breakfast_brunch', 'title': 'Break...
# 21   [{'alias': 'newamerican', 'title': 'American (...
# 22   [{'alias': 'tradamerican', 'title': 'American ...
# 23   [{'alias': 'newamerican', 'title': 'American (...
# 24   [{'alias': 'chinese', 'title': 'Chinese'}, {'a...
# 25   [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 26   [{'alias': 'southern', 'title': 'Southern'}, {...
# 27          [{'alias': 'mexican', 'title': 'Mexican'}]
# 28   [{'alias': 'newamerican', 'title': 'American (...
# 29   [{'alias': 'newamerican', 'title': 'American (...
# ..                                                 ...
# 90   [{'alias': 'tradamerican', 'title': 'American ...
# 91   [{'alias': 'steak', 'title': 'Steakhouses'}, {...
# 92   [{'alias': 'burgers', 'title': 'Burgers'}, {'a...
# 93   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 94   [{'alias': 'tradamerican', 'title': 'American ...
# 95   [{'alias': 'tradamerican', 'title': 'American ...
# 96   [{'alias': 'newamerican', 'title': 'American (...
# 97   [{'alias': 'newamerican', 'title': 'American (...
# 98   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 99   [{'alias': 'asianfusion', 'title': 'Asian Fusi...
# 100  [{'alias': 'steak', 'title': 'Steakhouses'}, {...
# 101  [{'alias': 'steak', 'title': 'Steakhouses'}, {...
# 102  [{'alias': 'soulfood', 'title': 'Soul Food'}, ...
# 103  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...
# 104  [{'alias': 'brazilian', 'title': 'Brazilian'},...
# 105  [{'alias': 'japanese', 'title': 'Japanese'}, {...
# 106  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 107  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...
# 108  [{'alias': 'steak', 'title': 'Steakhouses'}, {...
# 109  [{'alias': 'italian', 'title': 'Italian'}, {'a...
# 110         [{'alias': 'italian', 'title': 'Italian'}]
# 111  [{'alias': 'italian', 'title': 'Italian'}, {'a...
# 112  [{'alias': 'newamerican', 'title': 'American (...
# 113         [{'alias': 'italian', 'title': 'Italian'}]
# 114  [{'alias': 'steak', 'title': 'Steakhouses'}, {...
# 115  [{'alias': 'newamerican', 'title': 'American (...
# 116  [{'alias': 'breakfast_brunch', 'title': 'Break...
# 117  [{'alias': 'newamerican', 'title': 'American (...
# 118  [{'alias': 'asianfusion', 'title': 'Asian Fusi...
# 119  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...
#
#                                            coordinates   display_phone  \
# 0    {'latitude': 36.1006939, 'longitude': -115.209...  (702) 952-2500
# 1    {'latitude': 36.10433, 'longitude': -115.17559...  (702) 730-6700
# 2       {'latitude': 36.0704, 'longitude': -115.22495}  (702) 221-4120
# 3    {'latitude': 36.0864753723145, 'longitude': -1...  (702) 220-9224
# 4      {'latitude': 36.07251, 'longitude': -115.20691}  (702) 247-6528
# 5    {'latitude': 36.0759691458935, 'longitude': -1...  (702) 577-3232
# 6    {'latitude': 36.0603197442067, 'longitude': -1...  (702) 936-7200
# 7     {'latitude': 36.068141, 'longitude': -115.17486}  (702) 896-5154
# 8    {'latitude': 36.0927885119438, 'longitude': -1...  (702) 632-7407
# 9    {'latitude': 36.0994967, 'longitude': -115.220...  (702) 316-1999
# 10   {'latitude': 36.1112674181106, 'longitude': -1...  (702) 733-8901
# 11    {'latitude': 36.093063, 'longitude': -115.17631}  (702) 632-9300
# 12     {'latitude': 36.11499, 'longitude': -115.20754}  (702) 380-8487
# 13   {'latitude': 36.068496925708, 'longitude': -11...  (702) 948-8006
# 14     {'latitude': 36.09846, 'longitude': -115.14841}  (702) 998-9709
# 15   {'latitude': 36.113808, 'longitude': -115.174438}  (702) 693-8105
# 16   {'latitude': 36.0552438, 'longitude': -115.225...  (702) 776-7778
# 17   {'latitude': 36.055414, 'longitude': -115.241332}  (702) 998-9780
# 18     {'latitude': 36.05373, 'longitude': -115.17167}  (702) 617-0077
# 19   {'latitude': 36.052802, 'longitude': -115.171496}  (702) 270-2818
# 20   {'latitude': 36.1068693, 'longitude': -115.137...  (702) 477-6706
# 21   {'latitude': 36.1157859554742, 'longitude': -1...  (702) 731-7373
# 22   {'latitude': 36.0994443034537, 'longitude': -1...  (702) 597-7991
# 23   {'latitude': 36.102928, 'longitude': -115.173847}  (702) 740-6766
# 24   {'latitude': 36.1126313900105, 'longitude': -1...  (702) 693-8166
# 25   {'latitude': 36.1149449, 'longitude': -115.14997}  (702) 538-6135
# 26   {'latitude': 36.1088688031831, 'longitude': -1...  (702) 795-1016
# 27   {'latitude': 36.1125455097602, 'longitude': -1...  (702) 676-2003
# 28   {'latitude': 36.112279, 'longitude': -115.172397}  (702) 331-5100
# 29   {'latitude': 36.108854, 'longitude': -115.170512}  (702) 696-9080
# ..                                                 ...             ...
# 90   {'latitude': 36.0842933813, 'longitude': -115....  (702) 527-5200
# 91   {'latitude': 36.1026420010478, 'longitude': -1...  (702) 891-7318
# 92   {'latitude': 36.144557126741, 'longitude': -11...  (702) 256-0371
# 93   {'latitude': 36.137835215916, 'longitude': -11...  (702) 293-4444
# 94   {'latitude': 36.113309246227, 'longitude': -11...  (702) 732-3833
# 95   {'latitude': 36.1695941605572, 'longitude': -1...  (702) 388-2400
# 96   {'latitude': 36.171861, 'longitude': -115.146844}  (702) 384-4646
# 97   {'latitude': 36.1181806905551, 'longitude': -1...  (702) 254-4646
# 98   {'latitude': 36.1349154273748, 'longitude': -1...  (702) 722-2289
# 99   {'latitude': 36.1245818974195, 'longitude': -1...  (702) 607-0700
# 100  {'latitude': 36.171235, 'longitude': -115.144061}  (702) 382-1600
# 101  {'latitude': 36.1718063354492, 'longitude': -1...  (702) 384-2761
# 102  {'latitude': 36.055414, 'longitude': -115.241332}  (702) 998-9780
# 103  {'latitude': 36.1027408457725, 'longitude': -1...  (702) 740-6300
# 104  {'latitude': 36.1150184806622, 'longitude': -1...  (702) 431-4500
# 105  {'latitude': 36.0552438, 'longitude': -115.225...  (702) 776-7778
# 106  {'latitude': 36.157156, 'longitude': -115.1538...  (702) 384-8070
# 107  {'latitude': 36.1452874911923, 'longitude': -1...  (702) 363-5555
# 108  {'latitude': 36.1433720853764, 'longitude': -1...  (702) 761-7610
# 109  {'latitude': 36.106986091399, 'longitude': -11...  (702) 895-7561
# 110  {'latitude': 36.127858, 'longitude': -115.165969}  (702) 770-2040
# 111  {'latitude': 36.1179591, 'longitude': -115.279...  (702) 562-9000
# 1    {'address1': '3770 Las Vegas Blvd S', 'address...
# 2    {'address1': '6515 S Jones Blvd', 'address2': ...
# 3    {'address1': '5693 S Jones Blvd', 'address2': ...
# 4    {'address1': '4850 W Sunset Rd', 'address2': N...
# 5    {'address1': '6261 Dean Martin Dr', 'address2'...
# 6    {'address1': '7060 S Rainbow Blvd', 'address2'...
# 7    {'address1': '6659 Las Vegas Blvd S', 'address...
# 8    {'address1': '3950 Las Vegas Blvd S', 'address...
# 9    {'address1': '5785 W Tropicana Ave', 'address2...
# 10   {'address1': '4178 Koval Ln', 'address2': '', ...
# 11   {'address1': '3950 S Las Vegas Blvd', 'address...
# 12   {'address1': '4875 W Flamingo Rd', 'address2':...
# 13   {'address1': '6635 Las Vegas Blvd. South', 'ad...
# 14   {'address1': '5030 Paradise Rd', 'address2': N...
# 15   {'address1': '3600 S Las Vegas Blvd', 'address...
# 16   {'address1': '7377 S Jones Blvd', 'address2': ...
# 17   {'address1': '7320 S Rainbow Blvd', 'address2'...
# 18   {'address1': '7490 S Las Vegas Blvd', 'address...
# 19   {'address1': '7530 S Las Vegas Blvd', 'address...
# 20   {'address1': '4550 S Maryland Pkwy', 'address2...
# 21   {'address1': '3570 S Las Vegas Blvd', 'address...
# 22   {'address1': '3850 Las Vegas Blvd S', 'address...
# 23   {'address1': '3790 Las Vegas Blvd S', 'address...
# 24   {'address1': '3600 S Las Vegas Blvd', 'address...
# 25   {'address1': '620 E Flamingo Rd', 'address2': ...
# 26   {'address1': '3717 Las Vegas Blvd S', 'address...
# 27   {'address1': '4190 S Rainbow Blvd', 'address2'...
# 28   {'address1': '3655 Las Vegas Blvd S', 'address...
# 29   {'address1': '3667 Las Vegas Blvd S', 'address...
# ..                                                 ...
# 90   {'address1': '9275 W Russell Rd', 'address2': ...
# 91   {'address1': '3799 Las Vegas Blvd S', 'address...
# 92   {'address1': '9040 W Sahara', 'address2': '', ...
# 93   {'address1': '2797 S Maryland Pkwy', 'address2...
# 94   {'address1': '4195 South Grand Canyon Dr', 'ad...
# 95   {'address1': '301 Fremont St', 'address2': '',...
# 96   {'address1': '1 S Main St', 'address2': '', 'a...
# 97   {'address1': '3535 Las Vegas Blvd', 'address2'...
# 98   {'address1': '3025 Sammy Davis Jr Dr', 'addres...
# 99   {'address1': '3327 Las Vegas Blvd S', 'address...
# 100  {'address1': '128 Fremont St', 'address2': '',...
# 101  {'address1': '201 N 3rd St', 'address2': 'Ste ...
# 102  {'address1': '7320 S Rainbow Blvd', 'address2'...
# 103  {'address1': '3790 Las Vegas Blvd S', 'address...
# 104  {'address1': '360 E Flamingo Rd', 'address2': ...
# 105  {'address1': '7377 S Jones Blvd', 'address2': ...
# 106  {'address1': '1204 S Main St', 'address2': '',...
# 107  {'address1': '9014 W Sahara Ave', 'address2': ...
# 108  {'address1': '2535 S Las Vegas Blvd', 'address...
# 109  {'address1': '4550 S Maryland Pkwy', 'address2...
# 110  {'address1': '3131 Las Vegas Blvd S', 'address...
# 111  {'address1': '3945 S Durango Dr', 'address2': ...
# 112  {'address1': '113 N 4th St', 'address2': '', '...
# 113  {'address1': '412 E Flamingo Rd', 'address2': ...
# 114  {'address1': '440 S Rampart Blvd', 'address2':...
# 115  {'address1': '124 S 6th St', 'address2': 'Ste ...
# 116  {'address1': '5955 S Eastern Ave', 'address2':...
# 117  {'address1': '707 Carson Ave', 'address2': Non...
# 118  {'address1': 'The Venetian', 'address2': '3355...
# 119  {'address1': '7598 Vegas Dr', 'address2': '', ...
#
#                                                   name         phone price  \
# 0                                             Sushi 21  +17029522500    $$
# 1                           Bavette's Steakhouse & Bar  +17027306700  $$$$
# 2                                          Sierra Gold  +17022214120    $$
# 3                                             Mr Mamas  +17022209224     $
# 4                                        Phat Phrank's  +17022476528     $
# 5                                           SkinnyFATS  +17025773232    $$
# 6                                           Café Zupas  +17029367200    $$
# 7    California Pizza Kitchen at Town Square Las Vegas  +17028965154    $$
# 8                 Red Square Restaurant & Vodka Lounge  +17026327407   $$$
# 9                                        Payless Pizza  +17023161999     $
# 10                                    Ellis Island BBQ  +17027338901    $$
# 11                                          RM Seafood  +17026329300   $$$
# 12                   Blueberry Hill Family Restaurant   +17023808487    $$
# 13   Tommy Bahama Restaurant | Bar | Store - Las Vegas  +17029488006    $$
# 14                                2 Scoops of Aloha LV  +17029989709     $
# 15                                             Picasso  +17026938105  $$$$
# 16                            Soho Japanese Restaurant  +17027767778    $$
# 17                                      Soul Food Cafe  +17029989780    $$
# 18                                                IHOP  +17026170077    $$
# 19                                             Chili's  +17022702818    $$
# 20                              Breakfast & Grill Cafe  +17024776706     $
# 21                        Gordon Ramsay Hell's Kitchen  +17027317373   $$$
# 22                                  Dick's Last Resort  +17025977991    $$
# 23                                         Tom's Urban  +17027406766    $$
# 24                                             Jasmine  +17026938166  $$$$
# 25                                       Lotus of Siam  +17025386135    $$
# 26                               Bubba Gump Shrimp Co.  +17027951016    $$
# 27                                        Pepe's Tacos  +17026762003     $
# 28                                  HEXX kitchen + bar  +17023315100    $$
# 29                            Ocean One Bar and Grille  +17026969080    $$
# ..                                                 ...           ...   ...
# 90                                           DW Bistro  +17025275200    $$
# 91                          Tom Colicchio's Craftsteak  +17028917318  $$$$
# 92                                           Carl's Jr  +17022560371     $
# 93                               La Mojarra Loca Grill  +17022934444    $$
# 94                                         Fuddruckers  +17027323833    $$
# 95                                             D Grill  +17023882400    $$
# 96                                  Hash House A Go Go  +17023844646    $$
# 97                                  Hash House A Go Go  +17022544646    $$
# 98                                   El Dorado Cantina  +17027222289    $$
# 99                              SUSHISAMBA - Las Vegas  +17026070700   $$$
# 100                         Top of Binion's Steakhouse  +17023821600   $$$
# 101                                Triple George Grill  +17023842761    $$
# 102                                     Soul Food Cafe  +17029989780    $$
# 103                                          Chin Chin  +17027406300    $$
# 104                  Fogo de Chão Brazilian Steakhouse  +17024314500   $$$
# 105                           Soho Japanese Restaurant  +17027767778    $$
# 106                          Casa Don Juan  - Downtown  +17023848070    $$
# 107                                          Pizza Hut  +17023635555    $$
# 108                         Bazaar Meat by José Andrés  +17027617610  $$$$
# 109                      Cugino's Italian Deli & Pizza  +17028957561     $
# 110                                            Allegro  +17027702040   $$$
# 111                             Amore Taste of Chicago  +17025629000    $$
# 112                               Nacho Daddy Downtown  +17027787800    $$
# 113                   Buca di Beppo Italian Restaurant  +17028662867    $$
# 114                                         Echo & Rig  +17024893525    $$
# 115                                     Carson Kitchen  +17024739523    $$
# 116                                        Farmer Boys  +17022626221     $
# 117                                               Eat.  +17025341515    $$
# 118                                   TAO Asian Bistro  +17023888588   $$$
# 119                                          Carl's Jr  +17022882114     $
#
#      rating  review_count                                transactions  \
# 0       4.0           701                          [delivery, pickup]
# 1       4.5           204                                          []
# 2       3.5           227                                          []
# 3       4.5          2160                                          []
# 4       4.0           495                                          []
# 5       4.5          2086                          [delivery, pickup]
# 6       3.5           290                                          []
# 7       3.5           322                          [delivery, pickup]
# 8       4.0           621                    [restaurant_reservation]
# 9       4.0           373                          [delivery, pickup]
# 10      4.0           161                                          []
# 11      3.5           908                                          []
# 12      3.5           440                          [delivery, pickup]
# 13      4.0           468                                          []
# 14      4.0            51                                          []
# 15      4.5           844                                          []
# 16      4.5          1428                                          []
# 17      3.5           414                          [delivery, pickup]
# 18      3.0           220                                          []
# 19      3.0           236                                  [delivery]
# 20      4.0            87                          [delivery, pickup]
# 21      4.5          1368                                          []
# 22      3.0           824                                          []
# 23      3.5          1528                                          []
# 24      3.5           341                                          []
# 25      4.5           457                                          []
# 26      3.5           436                                          []
# 27      2.5           206                                          []
# 28      4.0          1954                                          []
# 29      3.5           874                                          []
# ..      ...           ...                                         ...
# 90      4.5          1182                                          []
# 91      4.0          2224                                          []
# 92      2.5            39                                          []
# 93      4.0           231                                          []
# 94      3.5           203                                          []
# 95      3.0           197                                          []
# 96      3.5           816                                          []
# 97      4.0          5479                                          []
# 98      4.5          1981  [restaurant_reservation, pickup, delivery]
# 99      4.0          2289                                          []
# 100     4.0           313                                          []
# 101     4.0          1016                                          []
# 102     3.5           414                          [pickup, delivery]
# 103     3.5           687                                          []
# 104     4.5          1084                                          []
# 105     4.5          1428                                          []
# 106     4.0           880                                    [pickup]
# 107     3.0            40                                          []
# 108     4.0           816                                          []
# 109     4.5           654                          [pickup, delivery]
# 110     3.5           433                                          []
# 111     4.0           677                          [pickup, delivery]
# 112     4.0          1192                          [pickup, delivery]
# 113     3.0           397                          [pickup, delivery]
# 114     4.5          2246                                          []
# 115     4.5          1878                                          []
# 116     3.0           168                                          []
# 117     4.0          2143                                          []
# 118     3.5          1504                                          []
# 119     2.5            29                                          []
#
#                                                    url
# 0    https://www.yelp.com/biz/sushi-21-las-vegas?ad...
# 1    https://www.yelp.com/biz/bavettes-steakhouse-a...
# 2    https://www.yelp.com/biz/sierra-gold-las-vegas...
# 3    https://www.yelp.com/biz/mr-mamas-las-vegas-7?...
# 4    https://www.yelp.com/biz/phat-phranks-las-vega...
# 5    https://www.yelp.com/biz/skinnyfats-las-vegas?...
# 6    https://www.yelp.com/biz/caf%C3%A9-zupas-las-v...
# 7    https://www.yelp.com/biz/california-pizza-kitc...
# 8    https://www.yelp.com/biz/red-square-restaurant...
# 118  https://www.yelp.com/biz/tao-asian-bistro-las-...
# 119  https://www.yelp.com/biz/carls-jr-las-vegas-30...
#
# [120 rows x 16 columns]

# %%
stats.ttest_ind(df['review_count'], newdf['review_count'], equal_var = False)
# Out:
# Ttest_indResult(statistic=8.302669710665775, pvalue=1.8004184699949375e-13)

# %%
stats.ttest_ind(df['rating'], newdf['stars'], equal_var = False)
# Out:
# Ttest_indResult(statistic=5.154171982492031, pvalue=9.318155579129605e-07)

# %%
x=df['rating'].value_counts()
x=x.sort_index()
#plot
plt.figure(figsize=(12,8))
ax= sns.barplot(x.index, x.values, alpha=0.8)
plt.title("Rating Distrubution")
plt.ylabel("Star Distrubution")
plt.xlabel('Star Ratings ', fontsize=12)
# Out:
# Text(0.5,0,'Star Ratings ')

# %%
data=[]
#rearranging data to suit the format needed for folium
rev_list=list(df['rating'].unique())
for rev in rev_list:
    subset= df[df['rating']==rating]
    data.append(subset[['latitude','longitude']].values.tolist())
#initialize at vegas
lat = 36.127430
lon = -115.138460
zoom_start=11
print("                     Vegas Review heatmap Animation ")

# basic map
m = folium.Map(location=[lat, lon], tiles="OpenStreetMap", zoom_start=zoom_start)
#inprovising the Heatmapwith time plugin to show variations across star ratings 
hm = plugins.HeatMapWithTime(data,max_opacity=0.3,auto_play=True,display_index=True,radius=7)
hm.add_to(m)
m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-2ea309dada91> in <module>()
#       3 rev_list=list(df['rating'].unique())
#       4 for rev in rev_list:
# ----> 5     subset= df[df['rating']==rating]
#       6     data.append(subset[['latitude','longitude']].values.tolist())
#       7 #initialize at vegas
#
# NameError: name 'rating' is not defined

# %%
x_vals = reduced_df["rating"]
y_vals = reduced_df["review_count"]
plt.plot(x_vals,
         y_vals, marker="o", linewidth=0.5,
         alpha=0.8)

# # Incorporate the other graph properties

plt.title(f"Analysis of ")
plt.xlim([x_vals.max(),x_vals.min()]) #Bonus
plt.ylabel("review_count")
plt.xlabel("rating")
plt.show()

# %%
yelp_business_df.head()

# %%
yelp_business_df.drop(['business_id','neighborhood','latitude','longitude','is_open'], axis = 1, inplace = True)
yelp_business_df.head()

# %%
yelp_business_df.city.value_counts()

# %%
yelp_business_df[['name','review_count','city','stars','categories']].sort_values(ascending=False,by='review_count')[0:40]

# %%
yelp_business_df[['name','review_count','city','stars','categories']].sort_values(ascending=True,by='stars')[0:40]

# %%
plt.figure(figsize=(12,4))
ax = sns.countplot(yelp_business_df['stars'])
plt.title('Distribution of Ratings');

# %%
business_cats=';'.join(yelp_business_df['categories'])
cats=pd.DataFrame(business_cats.split(';'),columns=['category'])
cats_ser = cats.category.value_counts()

cats_df = pd.DataFrame(cats_ser)
cats_df.reset_index(inplace=True)

plt.figure(figsize=(12,10))
f = sns.barplot( y= 'index',x = 'category' , data = cats_df.iloc[0:20])
f.set_ylabel('Category')
f.set_xlabel('Number of businesses');

# %%
df_lv = yelp_business_df.loc[yelp_business_df['city'].isin(['Las Vegas'])]
df_lv

# %%
yelp_business_df

# %%
df_CAny.head()

# %%
yelp_business_df.loc[yelp_business_df['name'].str.contains('Pizza Hut'),'state'].unique()
